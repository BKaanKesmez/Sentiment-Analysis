# %%
import sys
# !{sys.executable} -m pip install --upgrade pip
# !{sys.executable} -m pip install nltk scikit-learn joblib pandas matplotlib jupyterlab
# Out:
# Requirement already satisfied: pip in c:\users\bkaan\anaconda3\lib\site-packages (24.2)
# Collecting pip
#   Downloading pip-25.2-py3-none-any.whl.metadata (4.7 kB)
# Downloading pip-25.2-py3-none-any.whl (1.8 MB)
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/1.8 MB ? eta -:--:--
#    ----------------------- ---------------- 1.0/1.8 MB 4.2 MB/s eta 0:00:01
#    ---------------------------------------- 1.8/1.8 MB 4.0 MB/s eta 0:00:00
# Installing collected packages: pip
#   Attempting uninstall: pip
#     Found existing installation: pip 24.2
#     Uninstalling pip-24.2:
#       Successfully uninstalled pip-24.2
# Successfully installed pip-25.2
# Requirement already satisfied: nltk in c:\users\bkaan\anaconda3\lib\site-packages (3.9.1)
# Requirement already satisfied: scikit-learn in c:\users\bkaan\anaconda3\lib\site-packages (1.5.1)
# Requirement already satisfied: joblib in c:\users\bkaan\anaconda3\lib\site-packages (1.4.2)
# Requirement already satisfied: pandas in c:\users\bkaan\anaconda3\lib\site-packages (2.2.2)
# Requirement already satisfied: matplotlib in c:\users\bkaan\anaconda3\lib\site-packages (3.9.2)
# Requirement already satisfied: jupyterlab in c:\users\bkaan\anaconda3\lib\site-packages (4.2.5)
# Requirement already satisfied: click in c:\users\bkaan\anaconda3\lib\site-packages (from nltk) (8.1.7)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\bkaan\anaconda3\lib\site-packages (from nltk) (2024.9.11)
# Requirement already satisfied: tqdm in c:\users\bkaan\anaconda3\lib\site-packages (from nltk) (4.66.5)
# Requirement already satisfied: numpy>=1.19.5 in c:\users\bkaan\anaconda3\lib\site-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\bkaan\anaconda3\lib\site-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\bkaan\anaconda3\lib\site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\bkaan\anaconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\bkaan\anaconda3\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\bkaan\anaconda3\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\bkaan\anaconda3\lib\site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\bkaan\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\bkaan\anaconda3\lib\site-packages (from matplotlib) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\bkaan\anaconda3\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\bkaan\anaconda3\lib\site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\bkaan\anaconda3\lib\site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\bkaan\anaconda3\lib\site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: async-lru>=1.0.0 in c:\users\bkaan\anaconda3\lib\site-packages (from jupyterlab) (2.0.4)
# Requirement already satisfied: httpx>=0.25.0 in c:\users\bkaan\anaconda3\lib\site-packages (from jupyterlab) (0.27.0)
# Requirement already satisfied: ipykernel>=6.5.0 in c:\users\bkaan\anaconda3\lib\site-packages (from jupyterlab) (6.28.0)
# Requirement already satisfied: jinja2>=3.0.3 in c:\users\bkaan\anaconda3\lib\site-packages (from jupyterlab) (3.1.4)
# Requirement already satisfied: jupyter-core in c:\users\bkaan\anaconda3\lib\site-packages (from jupyterlab) (5.7.2)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in c:\users\bkaan\anaconda3\lib\site-packages (from jupyterlab) (2.2.0)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in c:\users\bkaan\anaconda3\lib\site-packages (from jupyterlab) (2.14.1)
# Requirement already satisfied: jupyterlab-server<3,>=2.27.1 in c:\users\bkaan\anaconda3\lib\site-packages (from jupyterlab) (2.27.3)
# Requirement already satisfied: notebook-shim>=0.2 in c:\users\bkaan\anaconda3\lib\site-packages (from jupyterlab) (0.2.3)
# Requirement already satisfied: setuptools>=40.1.0 in c:\users\bkaan\anaconda3\lib\site-packages (from jupyterlab) (75.1.0)
# Requirement already satisfied: tornado>=6.2.0 in c:\users\bkaan\anaconda3\lib\site-packages (from jupyterlab) (6.4.1)
# Requirement already satisfied: traitlets in c:\users\bkaan\anaconda3\lib\site-packages (from jupyterlab) (5.14.3)
# Requirement already satisfied: anyio>=3.1.0 in c:\users\bkaan\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (4.2.0)
# Requirement already satisfied: argon2-cffi>=21.1 in c:\users\bkaan\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (21.3.0)
# Requirement already satisfied: jupyter-client>=7.4.4 in c:\users\bkaan\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (8.6.0)
# Requirement already satisfied: jupyter-events>=0.9.0 in c:\users\bkaan\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (0.10.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in c:\users\bkaan\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (0.4.4)
# Requirement already satisfied: nbconvert>=6.4.4 in c:\users\bkaan\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (7.16.4)
# Requirement already satisfied: nbformat>=5.3.0 in c:\users\bkaan\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (5.10.4)
# Requirement already satisfied: overrides>=5.0 in c:\users\bkaan\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (7.4.0)
# Requirement already satisfied: prometheus-client>=0.9 in c:\users\bkaan\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (0.14.1)
# Requirement already satisfied: pywinpty>=2.0.1 in c:\users\bkaan\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (2.0.10)
# Requirement already satisfied: pyzmq>=24 in c:\users\bkaan\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (25.1.2)
# Requirement already satisfied: send2trash>=1.8.2 in c:\users\bkaan\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\bkaan\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (0.17.1)
# Requirement already satisfied: websocket-client>=1.7 in c:\users\bkaan\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (1.8.0)
# Requirement already satisfied: babel>=2.10 in c:\users\bkaan\anaconda3\lib\site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab) (2.11.0)
# Requirement already satisfied: json5>=0.9.0 in c:\users\bkaan\anaconda3\lib\site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab) (0.9.6)
# Requirement already satisfied: jsonschema>=4.18.0 in c:\users\bkaan\anaconda3\lib\site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab) (4.23.0)
# Requirement already satisfied: requests>=2.31 in c:\users\bkaan\anaconda3\lib\site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab) (2.32.3)
# Requirement already satisfied: idna>=2.8 in c:\users\bkaan\anaconda3\lib\site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->jupyterlab) (3.7)
# Requirement already satisfied: sniffio>=1.1 in c:\users\bkaan\anaconda3\lib\site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->jupyterlab) (1.3.0)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\bkaan\anaconda3\lib\site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab) (21.2.0)
# Requirement already satisfied: certifi in c:\users\bkaan\anaconda3\lib\site-packages (from httpx>=0.25.0->jupyterlab) (2025.4.26)
# Requirement already satisfied: httpcore==1.* in c:\users\bkaan\anaconda3\lib\site-packages (from httpx>=0.25.0->jupyterlab) (1.0.2)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\bkaan\anaconda3\lib\site-packages (from httpcore==1.*->httpx>=0.25.0->jupyterlab) (0.14.0)
# Requirement already satisfied: comm>=0.1.1 in c:\users\bkaan\anaconda3\lib\site-packages (from ipykernel>=6.5.0->jupyterlab) (0.2.1)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\bkaan\anaconda3\lib\site-packages (from ipykernel>=6.5.0->jupyterlab) (1.6.7)
# Requirement already satisfied: ipython>=7.23.1 in c:\users\bkaan\anaconda3\lib\site-packages (from ipykernel>=6.5.0->jupyterlab) (8.27.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\bkaan\anaconda3\lib\site-packages (from ipykernel>=6.5.0->jupyterlab) (0.1.6)
# Requirement already satisfied: nest-asyncio in c:\users\bkaan\anaconda3\lib\site-packages (from ipykernel>=6.5.0->jupyterlab) (1.6.0)
# Requirement already satisfied: psutil in c:\users\bkaan\anaconda3\lib\site-packages (from ipykernel>=6.5.0->jupyterlab) (5.9.0)
# Requirement already satisfied: decorator in c:\users\bkaan\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\bkaan\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab) (0.19.1)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\users\bkaan\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\bkaan\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab) (2.15.1)
# Requirement already satisfied: stack-data in c:\users\bkaan\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab) (0.2.0)
# Requirement already satisfied: colorama in c:\users\bkaan\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab) (0.4.6)
# Requirement already satisfied: wcwidth in c:\users\bkaan\anaconda3\lib\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab) (0.2.5)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in c:\users\bkaan\anaconda3\lib\site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab) (0.8.3)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\bkaan\anaconda3\lib\site-packages (from jinja2>=3.0.3->jupyterlab) (2.1.3)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\bkaan\anaconda3\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\bkaan\anaconda3\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\bkaan\anaconda3\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\bkaan\anaconda3\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab) (0.10.6)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\bkaan\anaconda3\lib\site-packages (from jupyter-core->jupyterlab) (3.10.0)
# Requirement already satisfied: pywin32>=300 in c:\users\bkaan\anaconda3\lib\site-packages (from jupyter-core->jupyterlab) (305.1)
# Requirement already satisfied: python-json-logger>=2.0.4 in c:\users\bkaan\anaconda3\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab) (2.0.7)
# Requirement already satisfied: pyyaml>=5.3 in c:\users\bkaan\anaconda3\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab) (6.0.1)
# Requirement already satisfied: rfc3339-validator in c:\users\bkaan\anaconda3\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in c:\users\bkaan\anaconda3\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab) (0.1.1)
# Collecting fqdn (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab)
#   Downloading fqdn-1.5.1-py3-none-any.whl.metadata (1.4 kB)
# Collecting isoduration (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab)
#   Downloading isoduration-20.11.0-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: jsonpointer>1.13 in c:\users\bkaan\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab) (2.1)
# Collecting uri-template (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab)
#   Downloading uri_template-1.3.0-py3-none-any.whl.metadata (8.8 kB)
# Collecting webcolors>=24.6.0 (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab)
#   Downloading webcolors-24.11.1-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: beautifulsoup4 in c:\users\bkaan\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab) (4.12.3)
# Requirement already satisfied: bleach!=5.0.0 in c:\users\bkaan\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab) (4.1.0)
# Requirement already satisfied: defusedxml in c:\users\bkaan\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in c:\users\bkaan\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab) (0.1.2)
# Requirement already satisfied: mistune<4,>=2.0.3 in c:\users\bkaan\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab) (2.0.4)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\bkaan\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab) (0.8.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\bkaan\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab) (1.5.0)
# Requirement already satisfied: tinycss2 in c:\users\bkaan\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab) (1.2.1)
# Requirement already satisfied: six>=1.9.0 in c:\users\bkaan\anaconda3\lib\site-packages (from bleach!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab) (1.16.0)
# Requirement already satisfied: webencodings in c:\users\bkaan\anaconda3\lib\site-packages (from bleach!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab) (0.5.1)
# Requirement already satisfied: fastjsonschema>=2.15 in c:\users\bkaan\anaconda3\lib\site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->jupyterlab) (2.16.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\bkaan\anaconda3\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->jupyterlab) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\bkaan\anaconda3\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->jupyterlab) (2.2.3)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\bkaan\anaconda3\lib\site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab) (1.17.1)
# Requirement already satisfied: pycparser in c:\users\bkaan\anaconda3\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab) (2.21)
# Requirement already satisfied: soupsieve>1.2 in c:\users\bkaan\anaconda3\lib\site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab) (2.5)
# Requirement already satisfied: arrow>=0.15.0 in c:\users\bkaan\anaconda3\lib\site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab) (1.2.3)
# Requirement already satisfied: executing in c:\users\bkaan\anaconda3\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab) (0.8.3)
# Requirement already satisfied: asttokens in c:\users\bkaan\anaconda3\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab) (2.0.5)
# Requirement already satisfied: pure-eval in c:\users\bkaan\anaconda3\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab) (0.2.2)
# Downloading webcolors-24.11.1-py3-none-any.whl (14 kB)
# Downloading fqdn-1.5.1-py3-none-any.whl (9.1 kB)
# Downloading isoduration-20.11.0-py3-none-any.whl (11 kB)
# Downloading uri_template-1.3.0-py3-none-any.whl (11 kB)
# Installing collected packages: webcolors, uri-template, fqdn, isoduration
#
#    ---------------------------------------- 4/4 [isoduration]
#
# Successfully installed fqdn-1.5.1 isoduration-20.11.0 uri-template-1.3.0 webcolors-24.11.1

# %% [markdown]
# DOWNLOADING NLTK DATASETS

# %%
import nltk
nltk.download('movie_reviews')
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package movie_reviews to
# [nltk_data]     C:\Users\bkaan\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\movie_reviews.zip.
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\bkaan\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\bkaan\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# True

# %% [markdown]
# DATA LOADING AND DISCOVERY

# %%
from nltk.corpus import movie_reviews
from collections import Counter
import random

documents = [(movie_reviews.raw(fid), cat)
             for cat in movie_reviews.categories()
             for fid in movie_reviews.fileids(cat)]
random.shuffle(documents)

X = [doc for doc, _ in documents]
y = [cat for _, cat in documents]

print("Toplam örnek:", len(X))
print("Sınıf dağılımı:", Counter(y))
# Out:
# Toplam örnek: 2000
# Sınıf dağılımı: Counter({'neg': 1000, 'pos': 1000})

# %% [markdown]
# TRAIN/TEST SPLIT

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, stratify=y, random_state=42)

print("Train:", len(X_train), "Test:", len(X_test))
# Out:
# Train: 1600 Test: 400

# %% [markdown]
# Pipeline: TF-IDF + Naive Bayes

# %%
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB

pipeline = Pipeline([
    ('tfidf', TfidfVectorizer(stop_words='english', max_df=0.85, ngram_range=(1,2))),
    ('clf', MultinomialNB())
])

pipeline.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('tfidf',
#                  TfidfVectorizer(max_df=0.85, ngram_range=(1, 2),
#                                  stop_words='english')),
#                 ('clf', MultinomialNB())])

# %% [markdown]
# VALIDATION

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import matplotlib.pyplot as plt
import numpy as np

y_pred = pipeline.predict(X_test)
print("Accuracy:", accuracy_score(y_test, y_pred))
print(classification_report(y_test, y_pred))

cm = confusion_matrix(y_test, y_pred, labels=pipeline.classes_)
plt.figure(figsize=(5,4))
plt.imshow(cm, interpolation='nearest')
plt.xticks(np.arange(len(pipeline.classes_)), pipeline.classes_)
plt.yticks(np.arange(len(pipeline.classes_)), pipeline.classes_)
plt.colorbar()
plt.title("Confusion Matrix")
plt.show()
# Out:
# Accuracy: 0.8125
#               precision    recall  f1-score   support
#
#          neg       0.84      0.78      0.81       200
#          pos       0.79      0.85      0.82       200
#
#     accuracy                           0.81       400
#    macro avg       0.81      0.81      0.81       400
# weighted avg       0.81      0.81      0.81       400

# %% [markdown]
# SAVING MODEL

# %%
import os, joblib
os.makedirs('models', exist_ok=True)
joblib.dump(pipeline, 'models/sentiment_model.pkl')
print("Model kaydedildi: models/sentiment_model.pkl")
# Out:
# Model kaydedildi: models/sentiment_model.pkl

# %% [markdown]
# PREDICT FUNCTION

# %%
def predict_text(text, model=pipeline):
    pred = model.predict([text])[0]
    probs = model.predict_proba([text])[0]
    classes = model.classes_
    return pred, dict(zip(classes, probs.round(3)))

print(predict_text("An amazing story, brilliant acting and great direction."))
print(predict_text("Boring, predictable and too long."))
# Out:
# ('pos', {'neg': 0.404, 'pos': 0.596})
# ('neg', {'neg': 0.635, 'pos': 0.365})

# %% [markdown]
# BASIC INTERACTIVE ENTERANCE

# %%
while True:
    text = input("Yorum gir (çıkmak için q): ")
    if text.lower() == 'q':
        break
    pred, probs = predict_text(text)
    print("Tahmin:", pred, "Olasılıklar:", probs)
# Out:
# Yorum gir (çıkmak için q):  q

# %%
with open("requirements.txt", "w") as f:
    f.write("nltk\nscikit-learn\njoblib\npandas\nmatplotlib\n")
print("requirements.txt oluşturuldu.")
# Out:
# requirements.txt oluşturuldu.

# %%
readme_content = """# Sentiment Analysis - Movie Reviews 🎬

This project uses the **NLTK** library's `movie_reviews` dataset to classify movie reviews as **positive** or **negative**.

## 🚀 Features
- Preloaded dataset from NLTK
- Text vectorization using TF-IDF
- Naive Bayes classifier
- Save and load trained models
- Predict sentiment from user input in terminal

## 📂 Project Structure
sentiment-analysis/
├── notebook.ipynb # Main Jupyter Notebook
├── requirements.txt # Required Python packages
├── README.md # Project documentation
└── models/ # (Optional) Saved models
"""
with open("README.md", "w", encoding="utf-8") as f:
    f.write(readme_content)

print("README.md file created successfully.")
# Out:
# README.md file created successfully.
